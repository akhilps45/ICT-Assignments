# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilps45/ICT-Assignments/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NUMPY PROBLEMS**

# %% [markdown]
# 1.Basic Array Operations
# Convert the mpg column into a NumPy array and calculate:
# ○ The mean, median, and standard deviation of mpg.
# ○ The number of cars with mpg greater than 25

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('/content/sample_data/auto-mpg.csv')
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
print(type(data))
print(type(np.array(data['mpg']))) #converting the mpg column to array
data_mpg = np.array(data['mpg'])
data_mpg
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# array([18. , 15. , 18. , 16. , 17. , 15. , 14. , 14. , 14. , 15. , 15. ,
#        14. , 15. , 14. , 24. , 22. , 18. , 21. , 27. , 26. , 25. , 24. ,
#        25. , 26. , 21. , 10. , 10. , 11. ,  9. , 27. , 28. , 25. , 25. ,
#        19. , 16. , 17. , 19. , 18. , 14. , 14. , 14. , 14. , 12. , 13. ,
#        13. , 18. , 22. , 19. , 18. , 23. , 28. , 30. , 30. , 31. , 35. ,
#        27. , 26. , 24. , 25. , 23. , 20. , 21. , 13. , 14. , 15. , 14. ,
#        17. , 11. , 13. , 12. , 13. , 19. , 15. , 13. , 13. , 14. , 18. ,
#        22. , 21. , 26. , 22. , 28. , 23. , 28. , 27. , 13. , 14. , 13. ,
#        14. , 15. , 12. , 13. , 13. , 14. , 13. , 12. , 13. , 18. , 16. ,
#        18. , 18. , 23. , 26. , 11. , 12. , 13. , 12. , 18. , 20. , 21. ,
#        22. , 18. , 19. , 21. , 26. , 15. , 16. , 29. , 24. , 20. , 19. ,
#        15. , 24. , 20. , 11. , 20. , 21. , 19. , 15. , 31. , 26. , 32. ,
# ...

# %%
#mean value
mean = np.mean(data_mpg)
print(f'Mean value:{mean}')
#median value
median = np.median(data_mpg)
print(f'Median value:{median}')
#standard deviation
std = np.std(data_mpg)
print(f'Standard Deviation:{std}')
#The number of cars with mpg greater than 25
print(f'Number of cars with mpg greater than 25:{np.sum(data_mpg>25)}')
# Out:
# Mean value:23.514572864321607
# Median value:23.0
# Standard Deviation:7.806159061274433
# Number of cars with mpg greater than 25:158

# %% [markdown]
# 2. Filtering
# Using NumPy, filter all cars with more than 6 cylinders.
# Return the corresponding car_name as a list.

# %%
n = np.array(data[data['cylinders']>6]['car name'])
print(list(n))
# Out:
# ['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite', 'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se', "plymouth 'cuda 340", 'chevrolet monte carlo', 'buick estate wagon (sw)', 'ford f250', 'chevy c20', 'dodge d200', 'hi 1200d', 'chevrolet impala', 'pontiac catalina brougham', 'ford galaxie 500', 'plymouth fury iii', 'dodge monaco (sw)', 'ford country squire (sw)', 'pontiac safari (sw)', 'chevrolet impala', 'pontiac catalina', 'plymouth fury iii', 'ford galaxie 500', 'amc ambassador sst', 'mercury marquis', 'buick lesabre custom', 'oldsmobile delta 88 royale', 'chrysler newport royal', 'amc matador (sw)', 'chevrolet chevelle concours (sw)', 'ford gran torino (sw)', 'plymouth satellite custom (sw)', 'buick century 350', 'amc matador', 'chevrolet malibu', 'ford gran torino', 'dodge coronet custom', 'mercury marquis brougham', 'chevrolet caprice classic', 'ford
# ...

# %% [markdown]
# 3.Statistical Analysis
# Compute the 25th, 50th, and 75th percentiles of the weight column using NumPy.

# %%
import numpy as np
data_weight = np.array(data.weight)
a = np.percentile(data_weight,25)
b = np.percentile(data_weight,50)
c = np.percentile(data_weight,75)
print(f'25th percentile:{a}')
print(f'50th percentile:{b}')
print(f'75th percentile:{c}')
# Out:
# 25th percentile:2223.75
# 50th percentile:2803.5
# 75th percentile:3608.0

# %% [markdown]
# 4.Array Manipulation
# Convert the acceleration column into a NumPy array and normalize its values
# (scale between 0 and 1)

# %%
col1 = np.array(data['acceleration'])
print(type(col1))
data_normal = (col1 - np.min(col1)) / (np.max(col1) - np.min(col1))
print(data_normal)
# Out:
# <class 'numpy.ndarray'>
# [0.23809524 0.20833333 0.17857143 0.23809524 0.14880952 0.11904762
#  0.05952381 0.0297619  0.11904762 0.0297619  0.11904762 0.
#  0.08928571 0.11904762 0.41666667 0.44642857 0.44642857 0.47619048
#  0.38690476 0.74404762 0.56547619 0.38690476 0.56547619 0.26785714
#  0.41666667 0.35714286 0.41666667 0.32738095 0.625      0.38690476
#  0.44642857 0.35714286 0.6547619  0.29761905 0.44642857 0.44642857
#  0.44642857 0.44642857 0.23809524 0.20833333 0.32738095 0.29761905
#  0.20833333 0.23809524 0.23809524 0.32738095 0.6547619  0.41666667
#  0.38690476 0.35714286 0.35714286 0.68452381 0.38690476 0.6547619
#  0.5952381  0.6547619  0.74404762 0.44642857 0.53571429 0.92261905
#  0.68452381 0.50595238 0.23809524 0.23809524 0.32738095 0.29761905
#  0.20833333 0.17857143 0.32738095 0.32738095 0.26785714 0.32738095
#  0.26785714 0.35714286 0.47619048 0.35714286 0.38690476 0.5952381
#  0.68452381 0.5952381  0.47619048 0.53571429 0.38690476 0.41666667
# ...

# %% [markdown]
# 5. Broadcasting :
# Increase all horsepower values by 10% and store the updated values in a new
# NumPy array. Handle missing data (if any) by replacing it with the mean of the
# column before applying the increase.
#
# ```
# # This is formatted as code
# ```

# %%
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
hp = data.horsepower
hp
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 393     86
# 394     52
# 395     84
# 396     79
# 397     82
# Name: horsepower, Length: 398, dtype: object

# %%
hp = hp.replace('?', np.nan)
hp = pd.to_numeric(hp)
mean_hp = np.mean(hp)
hp1 = np.where(np.isnan(hp), mean_hp, hp)
hp = hp1 * 1.1
print(hp)
# Out:
# [143.         181.5        165.         165.         154.
#  217.8        242.         236.5        247.5        209.
#  187.         176.         165.         247.5        104.5
#  104.5        106.7         93.5         96.8         50.6
#   95.7         99.         104.5        124.3         99.
#  236.5        220.         231.         212.3         96.8
#   99.         104.5        114.91632653 110.         115.5
#  110.          96.8        110.         181.5        192.5
#  168.3        165.         198.         187.         192.5
#  121.          79.2        110.          96.8         94.6
#   99.          77.          83.6         71.5         75.9
#   66.          77.         104.5         88.          59.4
#   99.          94.6        181.5        192.5        165.
#  168.3        165.         228.8        170.5        176.
#  209.         106.7        165.         143.         154.
#  165.         123.2         83.6         95.7         75.9
# ...

# %% [markdown]
# 6. Boolean Indexing :
# Find the average displacement of cars with an origin of 2 (Europe) using NumPy
# indexing.

# %%
disp = np.array(data[data["origin"]==2]["displacement"])
print(np.mean(disp))
# Out:
# 109.14285714285714

# %% [markdown]
# 7. Matrix Operations :
# Create a 2D NumPy array containing the columns mpg, horsepower, and weight.
# Compute the dot product of this matrix with a given vector [1, 0.5, -0.2].

# %%
matrix = np.column_stack((data_mpg, hp1, data_weight))
matrix
# Out:
# array([[  18.,  130., 3504.],
#        [  15.,  165., 3693.],
#        [  18.,  150., 3436.],
#        ...,
#        [  32.,   84., 2295.],
#        [  28.,   79., 2625.],
#        [  31.,   82., 2720.]])

# %%
vector = np.array([1, 0.5, -0.2])
dot_product = np.dot(matrix, vector)
dot_product
# Out:
# array([-617.8       , -641.1       , -594.2       , -595.6       ,
#        -602.8       , -754.2       , -746.8       , -740.9       ,
#        -758.5       , -660.        , -612.6       , -627.8       ,
#        -662.2       , -490.7       , -402.9       , -497.1       ,
#        -488.3       , -453.9       , -355.        , -318.        ,
#        -465.9       , -417.        , -402.5       , -364.3       ,
#        -463.6       , -805.5       , -765.2       , -760.4       ,
#        -840.9       , -355.        , -379.8       , -373.1       ,
#        -331.96530612, -457.8       , -619.3       , -598.8       ,
#        -597.4       , -589.6       , -745.3       , -791.3       ,
#        -740.3       , -730.2       , -889.        , -851.2       ,
#        -927.5       , -519.4       , -423.6       , -587.4       ,
#        -565.8       , -378.        , -351.6       , -349.8       ,
#        -345.        , -291.1       , -253.1       , -309.8       ,
# ...

# %% [markdown]
# 8.Sorting :
# Use NumPy to sort the cars by model_year in descending order and display the first
# f
#  ive car names.

# %%
car_names_sorted = (data.sort_values("model year", ascending=False)["car name"].head(5).tolist())
car_names_sorted
# Out:
# ['chevy s-10', 'ford ranger', 'dodge rampage', 'vw pickup', 'ford mustang gl']

# %% [markdown]
# 9.Correlation :
# Compute the Pearson correlation coefficient between mpg and weight using
# NumPy.

# %%
corr_coef = np.corrcoef(data_mpg, data_weight)[0, 1]
print("Pearson correlation coefficient between mpg and weight:", corr_coef)
# Out:
# Pearson correlation coefficient between mpg and weight: -0.8317409332443352

# %% [markdown]
# 10.Conditional Aggregates :
# Calculate the mean mpg for cars grouped by the number of cylinders using NumPy
# techniques.

# %%
unique_cylinders = np.unique(data["cylinders"].values)
mean_mpg_by_cyl = {cyl: np.mean(data_mpg[data["cylinders"].values == cyl]) for cyl in unique_cylinders}
mean_mpg_by_cyl
# Out:
# {np.int64(3): np.float64(20.55),
#  np.int64(4): np.float64(29.28676470588235),
#  np.int64(5): np.float64(27.366666666666664),
#  np.int64(6): np.float64(19.985714285714284),
#  np.int64(8): np.float64(14.963106796116506)}

# %% [markdown]
# # **PANDAS PROBLEMS**

# %% [markdown]
# 1.Basic Exploration:
# Load the dataset into a Pandas DataFrame. Display:
# ○ The first 10 rows
# ○ The total number of rows and columns
# ○ Summary statistics for numerical columns

# %%
display(data.head(10))
print("Shape (rows, columns):", data.shape)
display(data.describe())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# 2.Filtering and Indexing :
# Find all cars manufactured in 1975 with a weight less than 3000. Return the
# DataFrame with selected columns: car_name, weight, and mpg.

# %%
filtered_data = data[(data["model year"] == 75) & (data["weight"] < 3000)][["car name", "weight", "mpg"]]
display(filtered_data)
# Out:
#               car name  weight   mpg
# 167     toyota corolla    2171  29.0
# 168         ford pinto    2639  23.0
# 169        amc gremlin    2914  20.0
# 170      pontiac astro    2592  23.0
# 171      toyota corona    2702  24.0
# 172  volkswagen dasher    2223  25.0
# 173         datsun 710    2545  24.0
# 174         ford pinto    2984  18.0
# 175  volkswagen rabbit    1937  29.0
# 177         audi 100ls    2694  23.0
# 178        peugeot 504    2957  23.0
# 179        volvo 244dl    2945  22.0
# 180          saab 99le    2671  25.0
# 181   honda civic cvcc    1795  33.0

# %% [markdown]
# 3.Handling Missing Data :
# Identify if there are any missing values in the dataset. Replace missing values in the
# horsepower column with the column's median.

# %%
missing_values = data.isnull().sum()
print("Missing values per column:\n", missing_values)
data["horsepower"] = pd.to_numeric(data["horsepower"], errors="coerce")
median_hp = data["horsepower"].median()
data["horsepower"] = data["horsepower"].fillna(median_hp)
print("Median horsepower:", median_hp)
# Out:
# Missing values per column:
#  mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64
# Median horsepower: 93.5

# %% [markdown]
# 4.Data Transformation :
# Add a new column power_to_weight_ratio, calculated as horsepower / weight.

# %%
data["power_to_weight_ratio"] = data["horsepower"] / data["weight"]
display(data[["horsepower", "weight", "power_to_weight_ratio"]].head())
# Out:
#    horsepower  weight  power_to_weight_ratio
# 0       130.0    3504               0.037100
# 1       165.0    3693               0.044679
# 2       150.0    3436               0.043655
# 3       150.0    3433               0.043694
# 4       140.0    3449               0.040591

# %% [markdown]
# 5.Group By :
# Group the cars by origin and calculate the mean mpg for each group.

# %%
mean_mpg_by_origin = data.groupby("origin")["mpg"].mean()
display(mean_mpg_by_origin)
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %% [markdown]
# 6.Sorting :
# Sort the DataFrame by mpg in descending order and display the top 10 cars with
# the highest mpg.
# Apply Function
# Create a new column performance_score using a custom function:
# def performance_score(row):
# return row['mpg'] * row['acceleration'] / row['weight']

# %%
def performance_score(row):
    return row["mpg"] * row["acceleration"] / row["weight"]


top10_mpg = data.sort_values(by="mpg", ascending=False).head(10)
display(top10_mpg[["car name", "mpg", "acceleration", "weight"]])
# Out:
#                             car name   mpg  acceleration  weight
# 322                        mazda glc  46.6          17.9    2110
# 329              honda civic 1500 gl  44.6          13.8    1850
# 325             vw rabbit c (diesel)  44.3          21.7    2085
# 394                        vw pickup  44.0          24.6    2130
# 326               vw dasher (diesel)  43.4          23.7    2335
# 244  volkswagen rabbit custom diesel  43.1          21.5    1985
# 309                        vw rabbit  41.5          14.7    2144
# 330             renault lecar deluxe  40.9          17.3    1835
# 324                       datsun 210  40.8          19.2    2110
# 247                   datsun b210 gx  39.4          18.6    2070

# %% [markdown]
# 7.Apply this function to each row and store the result in the new column.

# %%
data["performance_score"] = data.apply(performance_score, axis=1)
display(data[["car name", "mpg", "acceleration", "weight", "performance_score"]].head())
# Out:
#                     car name   mpg  acceleration  weight  performance_score
# 0  chevrolet chevelle malibu  18.0          12.0    3504           0.061644
# 1          buick skylark 320  15.0          11.5    3693           0.046710
# 2         plymouth satellite  18.0          11.0    3436           0.057625
# 3              amc rebel sst  16.0          12.0    3433           0.055928
# 4                ford torino  17.0          10.5    3449           0.051754

# %% [markdown]
# 8.Visualization Preparation :
# Generate a summary DataFrame with:
# ○ Average mpg, weight, and horsepower for each model_year.

# %%
summary_by_year = (data.groupby("model year")[["mpg", "weight", "horsepower"]].mean().reset_index())
summary_by_year.rename(columns={"mpg": "avg_mpg", "weight": "avg_weight", "horsepower": "avg_horsepower"},inplace=True,)
display(summary_by_year)
# Out:
#     model year    avg_mpg   avg_weight  avg_horsepower
# 0           70  17.689655  3372.793103      147.827586
# 1           71  21.250000  2995.428571      106.553571
# 2           72  18.714286  3237.714286      120.178571
# 3           73  17.100000  3419.025000      130.475000
# 4           74  22.703704  2877.925926       94.203704
# 5           75  20.266667  3176.800000      101.066667
# 6           76  21.573529  3078.735294      101.117647
# 7           77  23.375000  2997.357143      105.071429
# 8           78  24.061111  2861.805556       99.694444
# 9           79  25.093103  3055.344828      101.206897
# 10          80  33.696552  2436.655172       78.586207
# 11          81  30.334483  2522.931034       81.465517
# 12          82  31.709677  2453.548387       81.854839

# %% [markdown]
# 9.Exporting Data:
# Save a subset of the data containing only mpg, cylinders, horsepower, and weight
# for cars with mpg > 30 into a CSV file named high_mpg_cars.csv.

# %%
high_mpg_cars = data[data["mpg"] > 30][["mpg", "cylinders", "horsepower", "weight"]]
high_mpg_cars.to_csv("high_mpg_cars.csv", index=False)

# %% [markdown]
# 10.10.Finding Anomalies
#
# Identify potential outliers in the mpg column using the Interquartile Range (IQR) method. Specifically:
#
# ● Calculate the IQR for mpg.
#
# ● Define outliers as values less than Q1 - 1.5 * IQR or greater than Q3 + 1.5 * IQR.

# %%
Q1 = np.percentile(data["mpg"], 25)
Q2 = np.percentile(data["mpg"], 50)
Q3 = np.percentile(data["mpg"], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data[(data["mpg"] < lower_bound) | (data["mpg"] > upper_bound)][
    ["car name", "mpg", "model year"]
]
display(outliers)
# Out:
#       car name   mpg  model year
# 322  mazda glc  46.6          80

# %% [markdown]
# # **MATPLOTLIB PROBLEMS**

# %% [markdown]
# 1.What is the distribution of miles per gallon (mpg) in the dataset?
# Plot a histogram of mpg values.

# %%
import matplotlib.pyplot as plt
plt.hist(data["mpg"], bins=20, edgecolor="black")
plt.xlabel("Miles per Gallon (mpg)")
plt.ylabel("Frequency")
plt.title("Distribution of MPG in the Dataset")
plt.show()

# %% [markdown]
# 2.How does mpg vary with the number of cylinders? Use a boxplot to compare mpg across different cylinders.

# %%
data.boxplot(column="mpg", by="cylinders", grid=False)
plt.xlabel("Number of Cylinders")
plt.ylabel("Miles per Gallon (mpg)")
plt.title("MPG by Number of Cylinders")
plt.suptitle("")
plt.show()

# %% [markdown]
# 3.Is there a relationship between horsepower and mpg? Summarize your observation Plot a scatter plot of horsepower vs. mpg.

# %%
data["horsepower"] = pd.to_numeric(data["horsepower"], errors="coerce")
df_hp = data.dropna(subset=["horsepower"])
plt.scatter(df_hp["horsepower"], df_hp["mpg"], alpha=0.7)
plt.xlabel("Horsepower")
plt.ylabel("Miles per Gallon (mpg)")
plt.title("Horsepower vs. MPG")
plt.show()

# %% [markdown]
# 4.How does car weightinfluence mpg? Plot a scatter plot with a trend line for weight vs. mpg.

# %%
plt.scatter(data["weight"], data["mpg"], alpha=0.7, label="Data points")
z = np.polyfit(data["weight"], data["mpg"], 1)
p = np.poly1d(z)
plt.plot(data["weight"], p(data["weight"]), color="red", linewidth=2, label="Trend line")
plt.xlabel("Weight")
plt.ylabel("Miles per Gallon (mpg)")
plt.title("Weight vs. MPG with Trend Line")
plt.legend()
plt.show()

# %% [markdown]
# 5.Whatis the trend of average mpg across model years? Plot a line chart of average mpg per model year.

# %%
avg_mpg_per_year = data.groupby("model year")["mpg"].mean()
plt.plot(avg_mpg_per_year.index, avg_mpg_per_year.values, marker="o")
plt.xlabel("Model Year")
plt.ylabel("Average MPG")
plt.title("Average MPG Across Model Years")
plt.grid(True)
plt.show()

# %% [markdown]
# 6.How is the count of cars distributed by origin? Use a bar chart to show the number of carsfor each origin.

# %%
origin_counts = data["origin"].value_counts().sort_index()
origin_labels = {1: "USA", 2: "Europe", 3: "Japan"}
plt.bar(origin_counts.index.map(origin_labels), origin_counts.values)
plt.xlabel("Origin")
plt.ylabel("Number of Cars")
plt.title("Number of Cars by Origin")
plt.show()

# %% [markdown]
# 7.How do acceleration values vary across different cylinders? Use a boxplot of acceleration grouped by cylinders.

# %%
data.boxplot(column="acceleration", by="cylinders", grid=False)
plt.xlabel("Number of Cylinders")
plt.ylabel("Acceleration")
plt.title("Acceleration by Number of Cylinders")
plt.suptitle("")
plt.show()

# %% [markdown]
# 8.Which year had the most number of car entries? Plot a histogram or bar chart of car counts by model year.

# %%
car_counts_by_year = data["model year"].value_counts().sort_index()
plt.bar(car_counts_by_year.index, car_counts_by_year.values)
plt.xlabel("Model Year")
plt.ylabel("Number of Cars")
plt.title("Number of Cars by Model Year")
plt.show()

most_cars_year = car_counts_by_year.idxmax()
most_cars_count = car_counts_by_year.max()
print(f"The year with the most car entries is {most_cars_year} with {most_cars_count} cars.")
# Out:
# The year with the most car entries is 73 with 40 cars.

# %% [markdown]
# 9.Is there a clustering pattern among weight, horsepower, and mpg? Create a 3D scatter plot of these three variables.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(
    data["weight"].values,
    data["horsepower"].values,
    data["mpg"].values,
    c=data["mpg"].values,
    cmap="viridis",
    alpha=0.7,
)
ax.set_xlabel("Weight")
ax.set_ylabel("Horsepower")
ax.set_zlabel("MPG")
ax.set_title("3D Scatter Plot: Weight vs Horsepower vs MPG")
# Out:
# Text(0.5, 0.92, '3D Scatter Plot: Weight vs Horsepower vs MPG')

# %% [markdown]
# 10.Which 10 cars have the bestfuel efficiency? Plot a horizontal bar chartshowing the top 10 car names with the highest mpg.

# %%
top10_cars = (data.nlargest(10, "mpg")[["car name", "mpg"]].set_index("car name").sort_values("mpg"))
top10_cars["mpg"].plot(kind="barh", color="skyblue")
plt.xlabel("Miles per Gallon (mpg)")
plt.title("Top 10 Cars with Highest MPG")
plt.tight_layout()
plt.show()
